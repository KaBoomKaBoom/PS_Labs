# %% [markdown]
# Exercises from part 1

# %%
import matplotlib.pyplot as plt

# Forward bias data (direct polarization)
Udir = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45]
Idir = [0, 0, 0, 0, 1, 5.8, 27.1, 62.6, None, None]  # 'x' replaced with None

# Reverse bias data (inverse polarization)
Uinv = [0, 1, 3, 5, 10, 15, 20, 25, 30]
Iinv = [0, 3.05, 3.71, 4.25, 5.42, 6.62, 8.04, 9.94, 12.12]  # In microamperes

# Plot in two subplots
fig, axs = plt.subplots(1, 2, figsize=(14, 6))

# --- Forward Bias Plot ---
axs[0].plot(Udir, Idir, 'bo-', label='Forward (Idir) [mA]')
axs[0].set_title('Forward Bias Characteristic')
axs[0].set_xlabel('Voltage (V)')
axs[0].set_ylabel('Current (mA)')
axs[0].grid(True)
axs[0].legend()
axs[0].set_xlim(0, 0.5)

# --- Reverse Bias Plot ---
axs[1].plot(Uinv, Iinv, 'ro-', label='Reverse (Iinv) [μA]')
axs[1].set_title('Reverse Bias Characteristic')
axs[1].set_xlabel('Voltage (V)')
axs[1].set_ylabel('Current (μA)')
axs[1].grid(True)
axs[1].legend()
axs[1].set_xlim(0, 30)

plt.suptitle('Volt-Ampere Characteristics of Diode D1', fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
Ts = 0.01
t = np.arange(0, 5, Ts)

# Generate white noise
x1 = np.random.rand(len(t))

# Plot the noise
plt.figure(figsize=(10, 6))
plt.plot(t, x1)
plt.title('1.1 White Noise')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(x1, bins=100, density=True)
plt.title('1.2 Histogram of White Noise')
plt.xlabel('Amplitude')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
Ts2 = 0.001
t2 = np.arange(0, 5, Ts2)
x2 = np.random.rand(len(t2))

plt.figure(figsize=(10, 6))
plt.plot(t2, x2)
plt.title('1.3 White Noise with Ts = 0.001')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(x2, bins=500, density=True)
plt.title('1.4 Histogram of White Noise with Ts = 0.001')
plt.xlabel('Amplitude')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import lfilter

# Define parameters
Ts = 0.01  # Sampling time
om0 = 2 * np.pi  # Natural frequency in rad/s
dz = 0.005  # Damping factor
A = 1  # Amplitude
oms = om0 * Ts  # Normalized frequency

# Filter coefficients
a = [1 + 2 * dz * oms + oms**2, -2 * (1 + dz * oms), 1]
b = [A * 2 * oms**2]

# Generate time vector
t = np.arange(0, 50, Ts)

# Generate white noise signal x1
x1 = np.random.rand(len(t))
plt.figure(figsize=(10, 5))
plt.plot(t, x1, label='Original signal')
plt.grid(True)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Original White Noise')
plt.legend()
plt.show()
# Apply the filter
y1 = lfilter(b, a, x1)

# Plot the filtered signal
plt.figure(figsize=(10, 5))
plt.plot(t, y1, label='Filtered Signal (y1)')
plt.grid(True)
plt.xlabel('Time (s)')
plt.ylabel('Function y(t)')
plt.title('Filtering Noise with a Second-Order Filter')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import lfilter

# Define parameters
Ts = 0.001  # Sampling time
om0 = 2 * np.pi  # Natural frequency in rad/s
dz = 0.005  # Damping factor
A = 1  # Amplitude
oms = om0 * Ts  # Normalized frequency

# Filter coefficients
a = [1 + 2 * dz * oms + oms**2, -2 * (1 + dz * oms), 1]
b = [A * 2 * oms**2]

# Generate time vector
t = np.arange(0, 50, Ts)

# Generate white noise signal x1
x1 = np.random.rand(len(t))
plt.figure(figsize=(10, 5))
plt.plot(t, x1, label='Original signal')
plt.grid(True)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Original White Noise')
plt.legend()
plt.show()
# Apply the filter
y1 = lfilter(b, a, x1)

# Plot the filtered signal
plt.figure(figsize=(10, 5))
plt.plot(t, y1, label='Filtered Signal (y1)')
plt.grid(True)
plt.xlabel('Time (s)')
plt.ylabel('Function y(t)')
plt.title('Filtering Noise with a Second-Order Filter')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

R = 50
m = np.arange(0, R)
s = 2 * m * (0.9**m)

plt.figure(figsize=(10, 6))
plt.stem(m, s)
plt.title('2.1 Original Signal')
plt.xlabel('Time Index n')
plt.ylabel('Amplitude')
plt.grid(True)
plt.show()

# %%
d = np.random.rand(len(m)) - 0.5
plt.figure(figsize=(10, 6))
plt.plot(m, d, label='Random Signal')
plt.title('2.2 Random Signals')
plt.xlabel('Time Index n')
plt.ylabel('Amplitude')
plt.legend()
plt.grid(True)
plt.show()


plt.figure(figsize=(10, 6))
plt.plot(m, s, label='Original Signal')
plt.plot(m, d, label='Random Signal')
plt.title('2.3 Original and Random Signals')
plt.xlabel('Time Index n')
plt.ylabel('Amplitude')
plt.legend()
plt.grid(True)
plt.show()

# %%
x = s + d

plt.figure(figsize=(10, 6))
plt.plot(m, s, label='Original Signal')
plt.plot(m, x, label='Noisy Signal')
plt.title('2.4 Original and Noisy Signals')
plt.xlabel('Time Index n')
plt.ylabel('Amplitude')
plt.legend()
plt.grid(True)
plt.show()

# %%
from scipy.signal import lfilter

def moving_average_filter(signal, M):
    b = np.ones(M) / M
    return lfilter(b, 1, signal)

# Apply MAF with M=3
M = 3
y = moving_average_filter(x, M)

plt.figure(figsize=(10, 6))
plt.plot(m, s, label='Original Signal')
plt.plot(m, x, label='Noisy Signal')
plt.plot(m, y, label='Filtered Signal (M=3)')
plt.title('2.5 Original, Noisy, and Filtered Signals')
plt.xlabel('Time Index n')
plt.ylabel('Amplitude')
plt.legend()
plt.grid(True)
plt.show()

# %%
# M=5
M = 5
y = moving_average_filter(x, M)

plt.figure(figsize=(10, 6))
plt.plot(m, s, label='Original Signal')
plt.plot(m, x, label='Noisy Signal')
plt.plot(m, y, label='Filtered Signal (M=5)')
plt.title('2.6.1 Original, Noisy, and Filtered Signals')
plt.xlabel('Time Index n')
plt.ylabel('Amplitude')
plt.legend()
plt.grid(True)
plt.show()

# M=10
M = 10
y = moving_average_filter(x, M)

plt.figure(figsize=(10, 6))
plt.plot(m, s, label='Original Signal')
plt.plot(m, x, label='Noisy Signal')
plt.plot(m, y, label='Filtered Signal (M=10)')
plt.title('2.6.2 Original, Noisy, and Filtered Signals')
plt.xlabel('Time Index n')
plt.ylabel('Amplitude')
plt.legend()
plt.grid(True)
plt.show()

# %%
from scipy.signal import sawtooth

R = 1
m1 = np.arange(0, R, 0.001)

# Generate a different signal
s1 = 2 * sawtooth(3 * np.pi * m1 + np.pi / 6)
d1 = np.random.rand(len(m1)) - 0.5
x1 = s1 + d1

# Apply MAF with M=20
M = 20
y1 = moving_average_filter(x1, M)

plt.figure(figsize=(10, 6))
plt.plot(m1, s1, label='Original Signal')
plt.plot(m1, x1, label='Noisy Signal')
plt.plot(m1, y1, label='Filtered Signal (M=20)')
plt.title('2.7 Original, Noisy, and Filtered Signals')
plt.xlabel('Time Index n')
plt.ylabel('Amplitude')
plt.legend()
plt.grid(True)
plt.show()

# %%
# M=50
M = 50
y1 = moving_average_filter(x1, M)

plt.figure(figsize=(10, 6))
plt.plot(m1, s1, label='Original Signal')
plt.plot(m1, x1, label='Noisy Signal')
plt.plot(m1, y1, label='Filtered Signal (M=50)')
plt.title('Original, Noisy, and Filtered Signals')
plt.xlabel('Time Index n')
plt.ylabel('Amplitude')
plt.legend()
plt.grid(True)
plt.show()

# M=100
M = 100
y1 = moving_average_filter(x1, M)

plt.figure(figsize=(10, 6))
plt.plot(m1, s1, label='Original Signal')
plt.plot(m1, x1, label='Noisy Signal')
plt.plot(m1, y1, label='Filtered Signal (M=100)')
plt.title('Original, Noisy, and Filtered Signals')
plt.xlabel('Time Index n')
plt.ylabel('Amplitude')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt

class LMSFilter:
    def __init__(self, filter_length, mu):
        self.L = filter_length
        self.mu = mu
        self.w = np.zeros(self.L)
    
    def filter(self, x, d):
        N = len(x)
        y = np.zeros(N)
        e = np.zeros(N)
        
        # Pad input for initial filter delay
        x_padded = np.pad(x, (self.L-1, 0), 'constant')
        
        for n in range(N):
            # Get current input window
            x_window = x_padded[n:n+self.L][::-1]
            
            # Calculate filter output
            y[n] = np.dot(self.w, x_window)
            
            # Calculate error
            e[n] = d[n] - y[n]
            
            # Update filter weights
            self.w = self.w + self.mu * e[n] * x_window
            
        return y, e

class RLSFilter:
    def __init__(self, filter_length, lambda_forget=0.99, delta=0.1):
        self.L = filter_length
        self.lambda_forget = lambda_forget
        self.w = np.zeros(self.L)
        self.P = np.eye(self.L) / delta
    
    def filter(self, x, d):
        N = len(x)
        y = np.zeros(N)
        e = np.zeros(N)
        
        # Pad input for initial filter delay
        x_padded = np.pad(x, (self.L-1, 0), 'constant')
        
        for n in range(N):
            # Get current input window
            x_window = x_padded[n:n+self.L][::-1]
            
            # Calculate Kalman gain
            k = self.P @ x_window / (self.lambda_forget + x_window.T @ self.P @ x_window)
            
            # Calculate filter output
            y[n] = np.dot(self.w, x_window)
            
            # Calculate error
            e[n] = d[n] - y[n]
            
            # Update filter weights
            self.w = self.w + k * e[n]
            
            # Update inverse correlation matrix
            self.P = (self.P - np.outer(k, x_window.T @ self.P)) / self.lambda_forget
            
        return y, e

# Example usage and demonstration
def demo_noise_cancellation():
    # Generate sample signals
    t = np.linspace(0, 1, 6000)
    desired_signal = np.sin(2 * np.pi * 10 * t)  # 10 Hz sine wave
    noise = 0.5 * np.random.randn(len(t))
    input_signal = desired_signal + noise
    
    # Apply LMS filter
    lms = LMSFilter(filter_length=128, mu=0.01)
    lms_output, lms_error = lms.filter(input_signal, desired_signal)
    
    # Apply RLS filter
    rls = RLSFilter(filter_length=128)
    rls_output, rls_error = rls.filter(input_signal, desired_signal)
    
    # Plot results
    plt.figure(figsize=(12, 8))
    
    plt.subplot(4, 1, 1)
    plt.plot(t, desired_signal)
    plt.title('Original Signal')
    plt.grid(True)
    
    plt.subplot(4, 1, 2)
    plt.plot(t, input_signal)
    plt.title('Noisy Signal')
    plt.grid(True)
    
    plt.subplot(4, 1, 3)
    plt.plot(t, lms_output)
    plt.title('LMS Filtered Signal')
    plt.grid(True)
    
    plt.subplot(4, 1, 4)
    plt.plot(t, rls_output)
    plt.title('RLS Filtered Signal')
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    demo_noise_cancellation()
